# %%
class Node:
    def __init__(self,data,next):
        self.data = data
        self.next = next
class LinkedList:
    def __init__(self):
        self.head = None
    def insert_at_begining(self,data):
        node = Node(data,self.head)
        self.head = node

    def print(self):
        if self.head is None:
            print("its empty")
            return
        
        itr = self.head
        llstr = ''
        while itr:
            llstr += str(itr.data)+'-->'
            itr = itr.next

        print(llstr)
    def get_head(self):
        if self.head is None:
            print("sorry!")
            return
        return self.head
ll= LinkedList()
ll.insert_at_begining(5)
ll.insert_at_begining(85)
ll.print()
print(ll.get_head())
# Out:
# 85-->5-->
# <__main__.Node object at 0x000001554BC7C690>

# %%
class Node:
    def __init__(self,data,next=None):
        self.data = data
        self.next = next

y = Node(1)
print(y.data)
# Out:
# 1

# %%
class Node:
    def __init__(self,data,next=None):
        self.data = data
        self.next =  next
class LinkedList:
    def __init__(self):
        self.head = None
    def insert_at_beg(self,data):
        node = Node(data,self.head)
        self.head = node

    def print(self):
        if self.head is None:
            print("s")
            return
        itr = self.head
        llstr = ''
        while itr:
            llstr+=str(itr.data) + '-->'
            itr = itr.next

        print(llstr)

s = LinkedList()
s.insert_at_beg(5)
s.insert_at_beg(3)
s.print()
# Out:
# 3-->5-->

# %%
from operator import le


class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

def arr_to_LL(a):
    if not a:
        return None
    head = Node(a[0])
    mover = head
    for i in a[1:]:
        new_node = Node(i)
        mover.next = new_node
        mover = new_node
    return head
def traversal(head):
    move = head
    while move:
        print(move.data,end = " ")
        move = move.next
    print()
def length_ll(head):
    move = head
    count = 0
    while move:
        count+=1
        move = move.next
    return count
def search(head,val):
    move = head
    while move:
        if move.data == val:
            return True
        move = move.next
    return False

arr = [2, 1, 3, 8]
head = arr_to_LL(arr)

traversal(head)
print(length_ll(head))
print(search(head,1))
# Out:
# 2 1 3 8
# 4
# True

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
def arr_to_Linkls(a):
    if not a:
        return None
    head = Node(a[0])
    move = head
    for val in a[1:]:
        ne  = Node(val)
        move.next = ne
        move = ne
    return head
def traves(head):
    move = head 
    while move:
        print(move.data,end =" ")
        move = move.next
def l(head):
    count = 0
    move = head
    while move:
        count+=1
        move = move.next
    return count
def se(head,val):
    move = head
    while move:
        if move == val:
            return True
        move = move.next
    return False

a = [1,6,2,4]
head = arr_to_Linkls(a)
traves(head)
print(f"length:{l(head)}")
print(search(head,2))
# Out:
# 1 6 2 4 length:4
# True

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

def arr_to_link(a):
    if not a:
        return 0
    head = Node(a[0])
    move = head 
    for val in a[1:]:
        ne = Node(val)
        move.next = ne
        move = ne
    return head
# def insert_at_beg(head,val):
#     temp = Node(val)
#     temp.next = head
#     return temp
def dlt_head(head):
    if not head:
        return None
    return head.next
def traversal(head):
    move = head
    while move:
        print(move.data,end='-->')
        move = move.next
    print('None')
# def tail(head):
#     move = head
#     while move.next:
#         move = move.next
#     return move
def dlt_tail(head):
    if not head :
        return None
    if (head.next == None):
        return None
    move = head
    while move.next.next:
        move = move.next
    move.next = None
    return head

a = [2,1,0,8]
head = arr_to_link(a)
# head = dlt_head(head)
# head1 = insert_at_beg(head,3)
t = dlt_tail(head)
traversal(t)
# Out:
# 2-->1-->0-->None

# %%
class Node:
    def __init__(self,data):
        self.data= data
        self.next = None
    
def arr_to_ll(a):
    head = Node(a[0])
    move = head
    for i in a[1:]:
        ne = Node(i)
        move.next = ne
        move = ne
    return head
def travers(head):
    if not head:
        return None
    move = head
    while move:
        print(move.data,end="-->")
        move = move.next
    print('None')
def dlt_k(head,k):
    if head == None:
        return head
    if k==1:
        head = head.next
        return head
    count = 0
    prev = None
    move = head
    while move:
        count+=1
        if count == k:
            prev.next = prev.next.next
            break
        prev = move
        move = move.next
    return head


a = [5,1,8,7]
head = arr_to_ll(a)
print(head.data)
print(travers(head))
d = dlt_k(head,3)
print(travers(head))
# Out:
# 5
# 5-->1-->8-->7-->None
# None
# 5-->1-->7-->None
# None

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
def arr_to_llist(a):
    head = Node(a[0])
    move = head
    for i in a[1:]:
        new_node=Node(i)
        move.next = new_node
        move = new_node
    return head

def tr(head):
    if not head:
        return None
    move = head
    while move:
        print(move.data,end='-->')
        move = move.next
    print('None')
def dlt_kth(head,k):
    if not head:
        return None
    if head.data == k:
        head = head.next
        return head
    move = head
    pr = None
    while move:
        if move.data == k:
            pr.next = pr.next.next
        pr = move
        move = move.next
    return head
    

a = [1,2,6,0]
head = arr_to_llist(a) 
print(tr(head))
c = dlt_kth(head,1)
print(tr(c))
# Out:
# 1-->2-->6-->0-->None
# None
# 2-->6-->0-->None
# None
